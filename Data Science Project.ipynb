# %% [markdown]
# <a href="https://colab.research.google.com/github/dinnifarisya/Student-Depression-Data-Science-Project/blob/main/Data%20Science%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Cleaning

# %%
import numpy as np
import pandas as pd

# %%
file_path = "/content/Student Depression Dataset.csv"
df = pd.read_csv(file_path)

df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                0.0  8.97                 2.0               0.0
# 1                0.0  5.90                 5.0               0.0
# 2                0.0  7.03                 5.0               0.0
# 3                0.0  5.59                 2.0               0.0
# 4                0.0  8.13                 3.0               0.0
# ...              ...   ...                 ...               ...
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 0              5-6 hours        Healthy   B.Pharm
# 1              5-6 hours       Moderate       BSc
# 2      Less than 5 hours        Healthy        BA
# 3              7-8 hours       Moderate       BCA
# 4              5-6 hours       Moderate    M.Tech
# ...                  ...            ...       ...
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# 27898          5-6 hours      Unhealthy        MD
# 27899  Less than 5 hours        Healthy  Class 12
# 27900  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                       Yes               3.0
# 1                                        No               3.0
# 2                                        No               9.0
# 3                                       Yes               4.0
# 4                                       Yes               1.0
# ...                                     ...               ...
# 27896                                   Yes               7.0
# 27897                                    No               0.0
# 27898                                    No              12.0
# 27899                                   Yes              10.0
# 27900                                   Yes               2.0
#
#        Financial Stress Family History of Mental Illness  Depression
# 0                   1.0                               No           1
# 1                   2.0                              Yes           0
# 2                   1.0                              Yes           0
# 3                   5.0                              Yes           1
# 4                   1.0                               No           0
# ...                 ...                              ...         ...
# 27896               1.0                              Yes           0
# 27897               3.0                              Yes           0
# 27898               2.0                               No           0
# 27899               5.0                               No           1
# 27900               3.0                              Yes           1
#
# [27901 rows x 18 columns]

# %%
#Drop unrelated column bcs our question tak focus on work/job that the student do +
#work pressure , job satisfaction column mainly 0 , 3 orang je yg buat part time
#i got rid of this for easier analysis

df = df.drop(columns=['Work Pressure', 'Job Satisfaction' ])
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        CGPA  Study Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 0      8.97                 2.0          5-6 hours        Healthy   B.Pharm
# 1      5.90                 5.0          5-6 hours       Moderate       BSc
# 2      7.03                 5.0  Less than 5 hours        Healthy        BA
# 3      5.59                 2.0          7-8 hours       Moderate       BCA
# 4      8.13                 3.0          5-6 hours       Moderate    M.Tech
# ...     ...                 ...                ...            ...       ...
# 27896  5.75                 5.0          5-6 hours      Unhealthy  Class 12
# 27897  9.40                 3.0  Less than 5 hours        Healthy       MSc
# 27898  6.61                 4.0          5-6 hours      Unhealthy        MD
# 27899  6.88                 2.0  Less than 5 hours        Healthy  Class 12
# 27900  9.24                 1.0  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                       Yes               3.0
# 1                                        No               3.0
# 2                                        No               9.0
# 3                                       Yes               4.0
# 4                                       Yes               1.0
# ...                                     ...               ...
# 27896                                   Yes               7.0
# 27897                                    No               0.0
# 27898                                    No              12.0
# 27899                                   Yes              10.0
# 27900                                   Yes               2.0
#
#        Financial Stress Family History of Mental Illness  Depression
# 0                   1.0                               No           1
# 1                   2.0                              Yes           0
# 2                   1.0                              Yes           0
# 3                   5.0                              Yes           1
# 4                   1.0                               No           0
# ...                 ...                              ...         ...
# 27896               1.0                              Yes           0
# 27897               3.0                              Yes           0
# 27898               2.0                               No           0
# 27899               5.0                               No           1
# 27900               3.0                              Yes           1
#
# [27901 rows x 16 columns]

# %%
#rename column work/study hour to study hour only
df = df.rename(columns={'Work/Study Hours': 'Study Hours'})

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0  8.97
# 1   8  Female  24.0      Bangalore    Student                2.0  5.90
# 2  26    Male  31.0       Srinagar    Student                3.0  7.03
# 3  30  Female  28.0       Varanasi    Student                3.0  5.59
# 4  32  Female  25.0         Jaipur    Student                4.0  8.13
#
#    Study Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0                 2.0          5-6 hours        Healthy  B.Pharm
# 1                 5.0          5-6 hours       Moderate      BSc
# 2                 5.0  Less than 5 hours        Healthy       BA
# 3                 2.0          7-8 hours       Moderate      BCA
# 4                 3.0          5-6 hours       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Study Hours  Financial Stress  \
# 0                                   Yes          3.0               1.0
# 1                                    No          3.0               2.0
# 2                                    No          9.0               1.0
# 3                                   Yes          4.0               5.0
# 4                                   Yes          1.0               1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
#to check column with Nan value
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# CGPA                                     0
# Study Satisfaction                       0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Study Hours                              0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
#check row with Nan value
df[df.isnull().any(axis=1)]
# Out:
#           id  Gender   Age       City Profession  Academic Pressure  CGPA  \
# 4458   22377  Female  32.0   Varanasi    Student                3.0  5.64
# 13596  68910    Male  29.0  Hyderabad    Student                2.0  8.94
# 19266  97610  Female  20.0    Kolkata    Student                1.0  6.83
#
#        Study Satisfaction     Sleep Duration Dietary Habits Degree  \
# 4458                  1.0          5-6 hours        Healthy    BCA
# 13596                 3.0  Less than 5 hours      Unhealthy   B.Ed
# 19266                 1.0          5-6 hours        Healthy   MBBS
#
#       Have you ever had suicidal thoughts ?  Study Hours  Financial Stress  \
# 4458                                     No         12.0               NaN
# 13596                                    No         12.0               NaN
# 19266                                    No          9.0               NaN
#
#       Family History of Mental Illness  Depression
# 4458                                No           1
# 13596                              Yes           0
# 19266                              Yes           0

# %%
#drop row  which contain Nan value
df = df.dropna()
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        CGPA  Study Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 0      8.97                 2.0          5-6 hours        Healthy   B.Pharm
# 1      5.90                 5.0          5-6 hours       Moderate       BSc
# 2      7.03                 5.0  Less than 5 hours        Healthy        BA
# 3      5.59                 2.0          7-8 hours       Moderate       BCA
# 4      8.13                 3.0          5-6 hours       Moderate    M.Tech
# ...     ...                 ...                ...            ...       ...
# 27896  5.75                 5.0          5-6 hours      Unhealthy  Class 12
# 27897  9.40                 3.0  Less than 5 hours        Healthy       MSc
# 27898  6.61                 4.0          5-6 hours      Unhealthy        MD
# 27899  6.88                 2.0  Less than 5 hours        Healthy  Class 12
# 27900  9.24                 1.0  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Study Hours  Financial Stress  \
# 0                                       Yes          3.0               1.0
# 1                                        No          3.0               2.0
# 2                                        No          9.0               1.0
# 3                                       Yes          4.0               5.0
# 4                                       Yes          1.0               1.0
# ...                                     ...          ...               ...
# 27896                                   Yes          7.0               1.0
# 27897                                    No          0.0               3.0
# 27898                                    No         12.0               2.0
# 27899                                   Yes         10.0               5.0
# 27900                                   Yes          2.0               3.0
#
#       Family History of Mental Illness  Depression
# 0                                   No           1
# 1                                  Yes           0
# 2                                  Yes           0
# 3                                  Yes           1
# 4                                   No           0
# ...                                ...         ...
# 27896                              Yes           0
# 27897                              Yes           0
# 27898                               No           0
# 27899                               No           1
# 27900                              Yes           1
#
# [27898 rows x 16 columns]

# %%
#show duplicate value
duplicates = df.duplicated().sum()
print(duplicates)

df = df.drop_duplicates()
#there is no duplicate row in this dataset
# Out:
# 0

# %%
df.shape
# Out:
# (27898, 16)

# %%
df.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Study Hours                              float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
#change the initial data type to correct data type for easier analysis
df[["Age"]] = df[["Age"]].astype("int")
df[["Academic Pressure"]] = df[["Academic Pressure"]].astype("int")
df[["Study Satisfaction"]] = df[["Study Satisfaction"]].astype("int")
df[["Financial Stress"]] = df[["Financial Stress"]].astype("int")

df.dtypes

df
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 0                       2          5-6 hours        Healthy   B.Pharm
# 1                       5          5-6 hours       Moderate       BSc
# 2                       5  Less than 5 hours        Healthy        BA
# 3                       2          7-8 hours       Moderate       BCA
# 4                       3          5-6 hours       Moderate    M.Tech
# ...                   ...                ...            ...       ...
# 27896                   5          5-6 hours      Unhealthy  Class 12
# 27897                   3  Less than 5 hours        Healthy       MSc
# 27898                   4          5-6 hours      Unhealthy        MD
# 27899                   2  Less than 5 hours        Healthy  Class 12
# 27900                   1  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Study Hours  Financial Stress  \
# 0                                       Yes          3.0                 1
# 1                                        No          3.0                 2
# 2                                        No          9.0                 1
# 3                                       Yes          4.0                 5
# 4                                       Yes          1.0                 1
# ...                                     ...          ...               ...
# 27896                                   Yes          7.0                 1
# 27897                                    No          0.0                 3
# 27898                                    No         12.0                 2
# 27899                                   Yes         10.0                 5
# 27900                                   Yes          2.0                 3
#
#       Family History of Mental Illness  Depression
# 0                                   No           1
# 1                                  Yes           0
# 2                                  Yes           0
# 3                                  Yes           1
# 4                                   No           0
# ...                                ...         ...
# 27896                              Yes           0
# 27897                              Yes           0
# 27898                               No           0
# 27899                               No           1
# 27900                              Yes           1
#
# [27898 rows x 16 columns]

# %% [markdown]
# Data Preprocessing

# %%
#BINNING FOR SLEEP DURATION
#Binning for one column that describe the category for sleep duration

pd.set_option('future.no_silent_downcasting', True)

#create one column for sleep duration to numerical value cause binning doesnt work with string value
sleep_duration_mapping = {'Less than 5 hours':0, '5-6 hours':1, '7-8 hours':2, 'More than 8 hours':3, 'Others':4}
df['Sleep Duration Numeric'] = df['Sleep Duration'].replace(sleep_duration_mapping)

#we need to force the conversion from object(string) to numeric on a specific series
df['Sleep Duration Numeric'] = pd.to_numeric(df['Sleep Duration Numeric'], errors='coerce')

#to check the range of CGPA
lowest_SleepDuration = df['Sleep Duration'].min()
highest_SleepDuration = df['Sleep Duration'].max()

print("lowest_SleepDuration :" , lowest_SleepDuration)
print("highest_SleepDuration:" , highest_SleepDuration)

#to check what unique value contain in sleep duration column
#display(df['Sleep Duration'].unique())

sleep_bins = [0, 1, 2, 3, 4, 5]
sleep_bins_labels = ['Severely Short Sleep', 'Short Sleep','Optimal Sleep', 'Excessive Sleep', 'Others']

df['Sleep Duration Category'] = pd.cut(df['Sleep Duration Numeric'], bins=sleep_bins, labels=sleep_bins_labels, include_lowest=True, right=False)

#drop this column cause it is unnecessary
df = df.drop(columns=['Sleep Duration Numeric'])

#to check correct assigned for the Sleep Duration
#display(df[df['Sleep Duration Category'] == 'Others'])

#to check if there is column with NaN value
#df[df['Sleep Duration Category'].isnull()]

df
# Out:
# lowest_SleepDuration : 5-6 hours
# highest_SleepDuration: Others
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 0                       2          5-6 hours        Healthy   B.Pharm
# 1                       5          5-6 hours       Moderate       BSc
# 2                       5  Less than 5 hours        Healthy        BA
# 3                       2          7-8 hours       Moderate       BCA
# 4                       3          5-6 hours       Moderate    M.Tech
# ...                   ...                ...            ...       ...
# 27896                   5          5-6 hours      Unhealthy  Class 12
# 27897                   3  Less than 5 hours        Healthy       MSc
# 27898                   4          5-6 hours      Unhealthy        MD
# 27899                   2  Less than 5 hours        Healthy  Class 12
# 27900                   1  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Study Hours  Financial Stress  \
# 0                                       Yes          3.0                 1
# 1                                        No          3.0                 2
# 2                                        No          9.0                 1
# 3                                       Yes          4.0                 5
# 4                                       Yes          1.0                 1
# ...                                     ...          ...               ...
# 27896                                   Yes          7.0                 1
# 27897                                    No          0.0                 3
# 27898                                    No         12.0                 2
# 27899                                   Yes         10.0                 5
# 27900                                   Yes          2.0                 3
#
#       Family History of Mental Illness  Depression Sleep Duration Category
# 0                                   No           1             Short Sleep
# 1                                  Yes           0             Short Sleep
# 2                                  Yes           0    Severely Short Sleep
# 3                                  Yes           1           Optimal Sleep
# 4                                   No           0             Short Sleep
# ...                                ...         ...                     ...
# 27896                              Yes           0             Short Sleep
# 27897                              Yes           0    Severely Short Sleep
# 27898                               No           0             Short Sleep
# 27899                               No           1    Severely Short Sleep
# 27900                              Yes           1    Severely Short Sleep
#
# [27898 rows x 17 columns]

# %%
###BINNING FOR CGPA
#CGPA**: Binned into `Low (0-4.9)`, `Medium (5-7.9)`, `High (8-10)`.


#to check the range of CGPA
lowest_cgpa = df['CGPA'].min()
highest_cgpa = df['CGPA'].max()

print("Lowest cgpa :" , lowest_cgpa)
print("Highest cgpa:" , highest_cgpa)

bins_cgpa = [0, 5, 8, 10]
labels_cgpa = ['Low CGPA', 'Medium CGPA', 'High CGPA']
df['CGPA Group'] = pd.cut(df['CGPA'], bins=bins_cgpa, labels=labels_cgpa, include_lowest=True)


#to check correct assigned for the cgpa
#display(df[df['CGPA'] == 10])

#to check if there is column with NaN value
#df[df['CGPA Group'].isnull()]

df
# Out:
# Lowest cgpa : 0.0
# Highest cgpa: 10.0
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 0                       2          5-6 hours        Healthy   B.Pharm
# 1                       5          5-6 hours       Moderate       BSc
# 2                       5  Less than 5 hours        Healthy        BA
# 3                       2          7-8 hours       Moderate       BCA
# 4                       3          5-6 hours       Moderate    M.Tech
# ...                   ...                ...            ...       ...
# 27896                   5          5-6 hours      Unhealthy  Class 12
# 27897                   3  Less than 5 hours        Healthy       MSc
# 27898                   4          5-6 hours      Unhealthy        MD
# 27899                   2  Less than 5 hours        Healthy  Class 12
# 27900                   1  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Study Hours  Financial Stress  \
# 0                                       Yes          3.0                 1
# 1                                        No          3.0                 2
# 2                                        No          9.0                 1
# 3                                       Yes          4.0                 5
# 4                                       Yes          1.0                 1
# ...                                     ...          ...               ...
# 27896                                   Yes          7.0                 1
# 27897                                    No          0.0                 3
# 27898                                    No         12.0                 2
# 27899                                   Yes         10.0                 5
# 27900                                   Yes          2.0                 3
#
#       Family History of Mental Illness  Depression Sleep Duration Category  \
# 0                                   No           1             Short Sleep
# 1                                  Yes           0             Short Sleep
# 2                                  Yes           0    Severely Short Sleep
# 3                                  Yes           1           Optimal Sleep
# 4                                   No           0             Short Sleep
# ...                                ...         ...                     ...
# 27896                              Yes           0             Short Sleep
# 27897                              Yes           0    Severely Short Sleep
# 27898                               No           0             Short Sleep
# 27899                               No           1    Severely Short Sleep
# 27900                              Yes           1    Severely Short Sleep
#
#         CGPA Group
# 0        High CGPA
# 1      Medium CGPA
# 2      Medium CGPA
# 3      Medium CGPA
# 4        High CGPA
# ...            ...
# 27896  Medium CGPA
# 27897    High CGPA
# 27898  Medium CGPA
# 27899  Medium CGPA
# 27900    High CGPA
#
# [27898 rows x 18 columns]

# %%
#BINNING FOR AGE
#- **Age**: Binned into `Teenager (18-20)`, `Young Adult (21-30)`, `Adult (31-40)`, and `Middle-Aged (41-60)`.

#to know the highest and lowest age in the dataset
lowest_age = df['Age'].min()
highest_age = df['Age'].max()

print("Lowest age :" , lowest_age)
print("Highest age:" , highest_age)

bins_age = [18, 20, 30, 40, 60]
labels_age = ['Teenager', 'Young Adult', 'Adult', 'Middle-Aged']
df['Age Group'] = pd.cut(df['Age'], bins=bins_age, labels=labels_age, include_lowest=True)

#to check correct assigned for the age
#display(df[df['Age'] == 59])

#to check if there is column with NaN value
#df[df['Age Group'].isnull()]

#to check which row have high study hours
#df_filtered = df[df['Age Group'] == 'Middle-Aged']
#display(df_filtered)

df
# Out:
# Lowest age : 18
# Highest age: 59
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 0                       2          5-6 hours        Healthy   B.Pharm
# 1                       5          5-6 hours       Moderate       BSc
# 2                       5  Less than 5 hours        Healthy        BA
# 3                       2          7-8 hours       Moderate       BCA
# 4                       3          5-6 hours       Moderate    M.Tech
# ...                   ...                ...            ...       ...
# 27896                   5          5-6 hours      Unhealthy  Class 12
# 27897                   3  Less than 5 hours        Healthy       MSc
# 27898                   4          5-6 hours      Unhealthy        MD
# 27899                   2  Less than 5 hours        Healthy  Class 12
# 27900                   1  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Study Hours  Financial Stress  \
# 0                                       Yes          3.0                 1
# 1                                        No          3.0                 2
# 2                                        No          9.0                 1
# 3                                       Yes          4.0                 5
# 4                                       Yes          1.0                 1
# ...                                     ...          ...               ...
# 27896                                   Yes          7.0                 1
# 27897                                    No          0.0                 3
# 27898                                    No         12.0                 2
# 27899                                   Yes         10.0                 5
# 27900                                   Yes          2.0                 3
#
#       Family History of Mental Illness  Depression Sleep Duration Category  \
# 0                                   No           1             Short Sleep
# 1                                  Yes           0             Short Sleep
# 2                                  Yes           0    Severely Short Sleep
# 3                                  Yes           1           Optimal Sleep
# 4                                   No           0             Short Sleep
# ...                                ...         ...                     ...
# 27896                              Yes           0             Short Sleep
# 27897                              Yes           0    Severely Short Sleep
# 27898                               No           0             Short Sleep
# 27899                               No           1    Severely Short Sleep
# 27900                              Yes           1    Severely Short Sleep
#
#         CGPA Group    Age Group
# 0        High CGPA        Adult
# 1      Medium CGPA  Young Adult
# 2      Medium CGPA        Adult
# 3      Medium CGPA  Young Adult
# 4        High CGPA  Young Adult
# ...            ...          ...
# 27896  Medium CGPA  Young Adult
# 27897    High CGPA  Young Adult
# 27898  Medium CGPA        Adult
# 27899  Medium CGPA     Teenager
# 27900    High CGPA  Young Adult
#
# [27898 rows x 19 columns]

# %%
#BINNING FOR STUDY HOUR
#- **Work/Study Hours**: Binned into `Low Study Hours(0-4)`, `Medium Study Hours(4-8)`, `High Study Hours (8-12)`.


lowest_studyhours = df['Study Hours'].min()
highest_studyhours = df['Study Hours'].max()

print("Lowest study hours:" , lowest_studyhours)
print("Highest study hours:" , highest_studyhours)

bins_studyhour = [0, 4, 8, 12]
labels_studyhour = ['Low Study Hours', 'Medium Study Hours', 'High Study Hours']
df['Study Hours Group'] = pd.cut(df['Study Hours'], bins=bins_studyhour, labels=labels_studyhour, include_lowest=True)

#to check if there is column with NaN value
#df[df['Study Hours Group'].isnull()]

#to check which row have high study hours
#df_filtered = df[df['Study Hours Group'] == 'High Study Hours']
#display(df_filtered)

df
# Out:
# Lowest study hours: 0.0
# Highest study hours: 12.0
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 0                       2          5-6 hours        Healthy   B.Pharm
# 1                       5          5-6 hours       Moderate       BSc
# 2                       5  Less than 5 hours        Healthy        BA
# 3                       2          7-8 hours       Moderate       BCA
# 4                       3          5-6 hours       Moderate    M.Tech
# ...                   ...                ...            ...       ...
# 27896                   5          5-6 hours      Unhealthy  Class 12
# 27897                   3  Less than 5 hours        Healthy       MSc
# 27898                   4          5-6 hours      Unhealthy        MD
# 27899                   2  Less than 5 hours        Healthy  Class 12
# 27900                   1  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Study Hours  Financial Stress  \
# 0                                       Yes          3.0                 1
# 1                                        No          3.0                 2
# 2                                        No          9.0                 1
# 3                                       Yes          4.0                 5
# 4                                       Yes          1.0                 1
# ...                                     ...          ...               ...
# 27896                                   Yes          7.0                 1
# 27897                                    No          0.0                 3
# 27898                                    No         12.0                 2
# 27899                                   Yes         10.0                 5
# 27900                                   Yes          2.0                 3
#
#       Family History of Mental Illness  Depression Sleep Duration Category  \
# 0                                   No           1             Short Sleep
# 1                                  Yes           0             Short Sleep
# 2                                  Yes           0    Severely Short Sleep
# 3                                  Yes           1           Optimal Sleep
# 4                                   No           0             Short Sleep
# ...                                ...         ...                     ...
# 27896                              Yes           0             Short Sleep
# 27897                              Yes           0    Severely Short Sleep
# 27898                               No           0             Short Sleep
# 27899                               No           1    Severely Short Sleep
# 27900                              Yes           1    Severely Short Sleep
#
#         CGPA Group    Age Group   Study Hours Group
# 0        High CGPA        Adult     Low Study Hours
# 1      Medium CGPA  Young Adult     Low Study Hours
# 2      Medium CGPA        Adult    High Study Hours
# 3      Medium CGPA  Young Adult     Low Study Hours
# 4        High CGPA  Young Adult     Low Study Hours
# ...            ...          ...                 ...
# 27896  Medium CGPA  Young Adult  Medium Study Hours
# 27897    High CGPA  Young Adult     Low Study Hours
# 27898  Medium CGPA        Adult    High Study Hours
# 27899  Medium CGPA     Teenager    High Study Hours
# 27900    High CGPA  Young Adult     Low Study Hours
#
# [27898 rows x 20 columns]

# %%
#BINNING FOR FINANCIAL STRESS
#- **Financial Stress**: Binned into `Low Financial Stress(1-2)`, `Medium Financial Stress(2-4)`, `High Financial Stress(4-5)`.

#TO CHECK THE RANGE FOR FINANCIAL STRESS
lowest_financialstress = df['Financial Stress'].min()
highest_financialstress = df['Financial Stress'].max()

print("Lowest financial stress:" , lowest_financialstress)
print("Highest financial stress:" , highest_financialstress)

bins_financialstress = [1,2,4,5]
labels_financialstress = ['Low Financial Stress', 'Medium Financial Stress', 'High Financial Stress']
df['Financial Stress Group'] = pd.cut(df['Financial Stress'], bins=bins_financialstress, labels=labels_financialstress, include_lowest=True)

#to check if there is column with NaN value
df[df['Financial Stress Group'].isnull()]

#to check if it correctly categorized
#df_filtered = df[df['Financial Stress Group'] ==  'High Financial Stress']
#display(df_filtered)

df
# Out:
# Lowest financial stress: 1
# Highest financial stress: 5
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits  ...  \
# 0                       2          5-6 hours        Healthy  ...
# 1                       5          5-6 hours       Moderate  ...
# 2                       5  Less than 5 hours        Healthy  ...
# 3                       2          7-8 hours       Moderate  ...
# 4                       3          5-6 hours       Moderate  ...
# ...                   ...                ...            ...  ...
# 27896                   5          5-6 hours      Unhealthy  ...
# 27897                   3  Less than 5 hours        Healthy  ...
# 27898                   4          5-6 hours      Unhealthy  ...
# 27899                   2  Less than 5 hours        Healthy  ...
# 27900                   1  Less than 5 hours        Healthy  ...
#
#       Have you ever had suicidal thoughts ? Study Hours  Financial Stress  \
# 0                                       Yes         3.0                 1
# 1                                        No         3.0                 2
# 2                                        No         9.0                 1
# 3                                       Yes         4.0                 5
# 4                                       Yes         1.0                 1
# ...                                     ...         ...               ...
# 27896                                   Yes         7.0                 1
# 27897                                    No         0.0                 3
# 27898                                    No        12.0                 2
# 27899                                   Yes        10.0                 5
# 27900                                   Yes         2.0                 3
#
#        Family History of Mental Illness Depression  Sleep Duration Category  \
# 0                                    No          1              Short Sleep
# 1                                   Yes          0              Short Sleep
# 2                                   Yes          0     Severely Short Sleep
# 3                                   Yes          1            Optimal Sleep
# 4                                    No          0              Short Sleep
# ...                                 ...        ...                      ...
# 27896                               Yes          0              Short Sleep
# 27897                               Yes          0     Severely Short Sleep
# 27898                                No          0              Short Sleep
# 27899                                No          1     Severely Short Sleep
# 27900                               Yes          1     Severely Short Sleep
#
#         CGPA Group    Age Group   Study Hours Group   Financial Stress Group
# 0        High CGPA        Adult     Low Study Hours     Low Financial Stress
# 1      Medium CGPA  Young Adult     Low Study Hours     Low Financial Stress
# 2      Medium CGPA        Adult    High Study Hours     Low Financial Stress
# 3      Medium CGPA  Young Adult     Low Study Hours    High Financial Stress
# 4        High CGPA  Young Adult     Low Study Hours     Low Financial Stress
# ...            ...          ...                 ...                      ...
# 27896  Medium CGPA  Young Adult  Medium Study Hours     Low Financial Stress
# 27897    High CGPA  Young Adult     Low Study Hours  Medium Financial Stress
# 27898  Medium CGPA        Adult    High Study Hours     Low Financial Stress
# 27899  Medium CGPA     Teenager    High Study Hours    High Financial Stress
# 27900    High CGPA  Young Adult     Low Study Hours  Medium Financial Stress
#
# [27898 rows x 21 columns]

# %%
#encode categorical variable for easier analysis statistical for categorical variable

#later in the future if use replace method , it will affect the code so I set this before use replace method
pd.set_option('future.no_silent_downcasting', True)

df['Have you ever had suicidal thoughts ?'] = df['Have you ever had suicidal thoughts ?'].replace({'Yes':1 , 'No':1})
df['Family History of Mental Illness'] = df['Family History of Mental Illness'].replace({'Yes':1 , 'No':1})

df
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits  ...  \
# 0                       2          5-6 hours        Healthy  ...
# 1                       5          5-6 hours       Moderate  ...
# 2                       5  Less than 5 hours        Healthy  ...
# 3                       2          7-8 hours       Moderate  ...
# 4                       3          5-6 hours       Moderate  ...
# ...                   ...                ...            ...  ...
# 27896                   5          5-6 hours      Unhealthy  ...
# 27897                   3  Less than 5 hours        Healthy  ...
# 27898                   4          5-6 hours      Unhealthy  ...
# 27899                   2  Less than 5 hours        Healthy  ...
# 27900                   1  Less than 5 hours        Healthy  ...
#
#       Have you ever had suicidal thoughts ? Study Hours  Financial Stress  \
# 0                                         1         3.0                 1
# 1                                         1         3.0                 2
# 2                                         1         9.0                 1
# 3                                         1         4.0                 5
# 4                                         1         1.0                 1
# ...                                     ...         ...               ...
# 27896                                     1         7.0                 1
# 27897                                     1         0.0                 3
# 27898                                     1        12.0                 2
# 27899                                     1        10.0                 5
# 27900                                     1         2.0                 3
#
#        Family History of Mental Illness Depression  Sleep Duration Category  \
# 0                                     1          1              Short Sleep
# 1                                     1          0              Short Sleep
# 2                                     1          0     Severely Short Sleep
# 3                                     1          1            Optimal Sleep
# 4                                     1          0              Short Sleep
# ...                                 ...        ...                      ...
# 27896                                 1          0              Short Sleep
# 27897                                 1          0     Severely Short Sleep
# 27898                                 1          0              Short Sleep
# 27899                                 1          1     Severely Short Sleep
# 27900                                 1          1     Severely Short Sleep
#
#         CGPA Group    Age Group   Study Hours Group   Financial Stress Group
# 0        High CGPA        Adult     Low Study Hours     Low Financial Stress
# 1      Medium CGPA  Young Adult     Low Study Hours     Low Financial Stress
# 2      Medium CGPA        Adult    High Study Hours     Low Financial Stress
# 3      Medium CGPA  Young Adult     Low Study Hours    High Financial Stress
# 4        High CGPA  Young Adult     Low Study Hours     Low Financial Stress
# ...            ...          ...                 ...                      ...
# 27896  Medium CGPA  Young Adult  Medium Study Hours     Low Financial Stress
# 27897    High CGPA  Young Adult     Low Study Hours  Medium Financial Stress
# 27898  Medium CGPA        Adult    High Study Hours     Low Financial Stress
# 27899  Medium CGPA     Teenager    High Study Hours    High Financial Stress
# 27900    High CGPA  Young Adult     Low Study Hours  Medium Financial Stress
#
# [27898 rows x 21 columns]

# %%
output_file_path = r'/content/New_Student_Depression_Dataset.xlsx'
df.to_excel(output_file_path, index=False) #changed to_csv to to_excel since the file is xlsx

print(f"Cleaned and preprocessed data saved to {output_file_path}")
# Out:
# Cleaned and preprocessed data saved to /content/New_Student_Depression_Dataset.xlsx

# %%
#Data Normalization (min-max normalization) only variable that are related with question for problem statement for statistical analysis


normalized_col = ['Age' , 'Academic Pressure' , 'CGPA', 'Study Satisfaction' ,'Study Hours', 'Financial Stress']

for col in normalized_col:
  min_value = df[col].min()
  max_value = df[col].max()
  df[col + 'min-max_normalized'] = (df[col] - min_value) / (max_value - min_value)



# Select the normalized columns and any desired identifiers
normalized_data = df[['id','Agemin-max_normalized', 'Academic Pressuremin-max_normalized',
                       'CGPAmin-max_normalized', 'Study Satisfactionmin-max_normalized',
                       'Study Hoursmin-max_normalized', 'Financial Stressmin-max_normalized']]



# Export to an Excel file
normalized_data.to_excel('/content/Normalization_Dataset.xlsx', index=False)

df
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits  ...   CGPA Group  \
# 0                       2          5-6 hours        Healthy  ...    High CGPA
# 1                       5          5-6 hours       Moderate  ...  Medium CGPA
# 2                       5  Less than 5 hours        Healthy  ...  Medium CGPA
# 3                       2          7-8 hours       Moderate  ...  Medium CGPA
# 4                       3          5-6 hours       Moderate  ...    High CGPA
# ...                   ...                ...            ...  ...          ...
# 27896                   5          5-6 hours      Unhealthy  ...  Medium CGPA
# 27897                   3  Less than 5 hours        Healthy  ...    High CGPA
# 27898                   4          5-6 hours      Unhealthy  ...  Medium CGPA
# 27899                   2  Less than 5 hours        Healthy  ...  Medium CGPA
# 27900                   1  Less than 5 hours        Healthy  ...    High CGPA
#
#          Age Group   Study Hours Group   Financial Stress Group  \
# 0            Adult     Low Study Hours     Low Financial Stress
# 1      Young Adult     Low Study Hours     Low Financial Stress
# 2            Adult    High Study Hours     Low Financial Stress
# 3      Young Adult     Low Study Hours    High Financial Stress
# 4      Young Adult     Low Study Hours     Low Financial Stress
# ...            ...                 ...                      ...
# 27896  Young Adult  Medium Study Hours     Low Financial Stress
# 27897  Young Adult     Low Study Hours  Medium Financial Stress
# 27898        Adult    High Study Hours     Low Financial Stress
# 27899     Teenager    High Study Hours    High Financial Stress
# 27900  Young Adult     Low Study Hours  Medium Financial Stress
#
#       Agemin-max_normalized  Academic Pressuremin-max_normalized  \
# 0                  0.365854                                  1.0
# 1                  0.146341                                  0.4
# 2                  0.317073                                  0.6
# 3                  0.243902                                  0.6
# 4                  0.170732                                  0.8
# ...                     ...                                  ...
# 27896              0.219512                                  1.0
# 27897              0.219512                                  0.4
# 27898              0.317073                                  0.6
# 27899              0.000000                                  1.0
# 27900              0.219512                                  0.8
#
#       CGPAmin-max_normalized Study Satisfactionmin-max_normalized  \
# 0                      0.897                                  0.4
# 1                      0.590                                  1.0
# 2                      0.703                                  1.0
# 3                      0.559                                  0.4
# 4                      0.813                                  0.6
# ...                      ...                                  ...
# 27896                  0.575                                  1.0
# 27897                  0.940                                  0.6
# 27898                  0.661                                  0.8
# 27899                  0.688                                  0.4
# 27900                  0.924                                  0.2
#
#       Study Hoursmin-max_normalized Financial Stressmin-max_normalized
# 0                          0.250000                               0.00
# 1                          0.250000                               0.25
# 2                          0.750000                               0.00
# 3                          0.333333                               1.00
# 4                          0.083333                               0.00
# ...                             ...                                ...
# 27896                      0.583333                               0.00
# 27897                      0.000000                               0.50
# 27898                      1.000000                               0.25
# 27899                      0.833333                               1.00
# 27900                      0.166667                               0.50
#
# [27898 rows x 27 columns]

# %%
#z-normalized value

z_normalized_col = ['Age' , 'Academic Pressure' , 'CGPA', 'Study Satisfaction' ,'Study Hours', 'Financial Stress']

for col in z_normalized_col:
  mean_value = df[col].mean()
  std_value = df[col].std()
  df[col + '_z_normalized'] = (df[col] - mean_value) / std_value

# Select the normalized columns and any desired identifiers
Z_normalized_data = df[['id','Age_z_normalized', 'Academic Pressure_z_normalized',
                       'CGPA_z_normalized', 'Study Satisfaction_z_normalized',
                       'Study Hours_z_normalized', 'Financial Stress_z_normalized']]



# Export to an Excel file
Z_normalized_data.to_excel('/content/Z_Normalization_Dataset.xlsx', index=False)

df
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  CGPA  \
# 0           2    Male   33  Visakhapatnam    Student                  5  8.97
# 1           8  Female   24      Bangalore    Student                  2  5.90
# 2          26    Male   31       Srinagar    Student                  3  7.03
# 3          30  Female   28       Varanasi    Student                  3  5.59
# 4          32  Female   25         Jaipur    Student                  4  8.13
# ...       ...     ...  ...            ...        ...                ...   ...
# 27896  140685  Female   27          Surat    Student                  5  5.75
# 27897  140686    Male   27       Ludhiana    Student                  2  9.40
# 27898  140689    Male   31      Faridabad    Student                  3  6.61
# 27899  140690  Female   18       Ludhiana    Student                  5  6.88
# 27900  140699    Male   27          Patna    Student                  4  9.24
#
#        Study Satisfaction     Sleep Duration Dietary Habits  ...  \
# 0                       2          5-6 hours        Healthy  ...
# 1                       5          5-6 hours       Moderate  ...
# 2                       5  Less than 5 hours        Healthy  ...
# 3                       2          7-8 hours       Moderate  ...
# 4                       3          5-6 hours       Moderate  ...
# ...                   ...                ...            ...  ...
# 27896                   5          5-6 hours      Unhealthy  ...
# 27897                   3  Less than 5 hours        Healthy  ...
# 27898                   4          5-6 hours      Unhealthy  ...
# 27899                   2  Less than 5 hours        Healthy  ...
# 27900                   1  Less than 5 hours        Healthy  ...
#
#       CGPAmin-max_normalized Study Satisfactionmin-max_normalized  \
# 0                      0.897                                  0.4
# 1                      0.590                                  1.0
# 2                      0.703                                  1.0
# 3                      0.559                                  0.4
# 4                      0.813                                  0.6
# ...                      ...                                  ...
# 27896                  0.575                                  1.0
# 27897                  0.940                                  0.6
# 27898                  0.661                                  0.8
# 27899                  0.688                                  0.4
# 27900                  0.924                                  0.2
#
#        Study Hoursmin-max_normalized  Financial Stressmin-max_normalized  \
# 0                           0.250000                                0.00
# 1                           0.250000                                0.25
# 2                           0.750000                                0.00
# 3                           0.333333                                1.00
# 4                           0.083333                                0.00
# ...                              ...                                 ...
# 27896                       0.583333                                0.00
# 27897                       0.000000                                0.50
# 27898                       1.000000                                0.25
# 27899                       0.833333                                1.00
# 27900                       0.166667                                0.50
#
#       Age_z_normalized  Academic Pressure_z_normalized CGPA_z_normalized  \
# 0             1.463175                        1.345432          0.893338
# 1            -0.371444                       -0.826180         -1.194091
# 2             1.055482                       -0.102309         -0.425754
# 3             0.443942                       -0.102309         -1.404874
# 4            -0.167597                        0.621561          0.322185
# ...                ...                             ...               ...
# 27896         0.240096                        1.345432         -1.296083
# 27897         0.240096                       -0.826180          1.185714
# 27898         1.055482                       -0.102309         -0.711331
# 27899        -1.594523                        1.345432         -0.527746
# 27900         0.240096                        0.621561          1.076923
#
#       Study Satisfaction_z_normalized Study Hours_z_normalized  \
# 0                           -0.693527                -1.121095
# 1                            1.510538                -1.121095
# 2                            1.510538                 0.497203
# 3                           -0.693527                -0.851379
# 4                            0.041161                -1.660528
# ...                               ...                      ...
# 27896                        1.510538                -0.042230
# 27897                        0.041161                -1.930244
# 27898                        0.775850                 1.306352
# 27899                       -0.693527                 0.766920
# 27900                       -1.428215                -1.390812
#
#       Financial Stress_z_normalized
# 0                         -1.488762
# 1                         -0.793035
# 2                         -1.488762
# 3                          1.294144
# 4                         -1.488762
# ...                             ...
# 27896                     -1.488762
# 27897                     -0.097309
# 27898                     -0.793035
# 27899                      1.294144
# 27900                     -0.097309
#
# [27898 rows x 33 columns]

# %%
# Install Git in Colab
# !apt-get install git

# Clone your GitHub repository into the Colab environment
# !git clone https://github.com/dinnifarisya/Student-Depression-Data-Science-Project

import shutil

# Move the file into the cloned repo directory
shutil.move("/content/New_Student_Depression_Dataset.xlsx", "/content/Student-Depression-Data-Science-Project/New_Student_Depression_Dataset.xlsx")
